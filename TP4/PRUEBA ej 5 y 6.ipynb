# %%
# PUNTO 5
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, accuracy_score
import matplotlib.pyplot as plt

# CARGA DE DATOS
# Reemplazar 'datos_entrenamiento.csv' y 'datos_testeo.csv' por los archivos reales
# train = pd.read_csv('datos_entrenamiento.csv')
# test = pd.read_csv('datos_testeo.csv')

# X_train = train[['col1', 'col2', ...]]  # Características de entrenamiento
# y_train = train['target']               # Objetivo entrenamiento (0/1)
# X_test = test[['col1', 'col2', ...]]    # Características de testeo
# y_test = test['target']                 # Objetivo testeo

# REGRESIÓN LOGÍSTICA
logit = LogisticRegression()
logit.fit(X_train, y_train)
y_prob_logit = logit.predict_proba(X_test)[:,1]
y_pred_logit = (y_prob_logit > 0.5).astype(int)

# KNN (K=5)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_prob_knn = knn.predict_proba(X_test)[:,1]
y_pred_knn = (y_prob_knn > 0.5).astype(int)

# MATRIZ DE CONFUSIÓN
print("Matriz de confusión Logit:")
print(confusion_matrix(y_test, y_pred_logit))
print("\nMatriz de confusión KNN:")
print(confusion_matrix(y_test, y_pred_knn))

# CURVAS ROC Y AUC
fpr_logit, tpr_logit, _ = roc_curve(y_test, y_prob_logit)
fpr_knn, tpr_knn, _ = roc_curve(y_test, y_prob_knn)
auc_logit = roc_auc_score(y_test, y_prob_logit)
auc_knn = roc_auc_score(y_test, y_prob_knn)

print(f"\nAUC Logit: {auc_logit:.3f}")
print(f"AUC KNN: {auc_knn:.3f}")

# ACCURACY
acc_logit = accuracy_score(y_test, y_pred_logit)
acc_knn = accuracy_score(y_test, y_pred_knn)
print(f"\nAccuracy Logit: {acc_logit:.3f}")
print(f"Accuracy KNN: {acc_knn:.3f}")

# GRAFICA ROC
plt.figure()
plt.plot(fpr_logit, tpr_logit, label=f'Logit (AUC={auc_logit:.2f})')
plt.plot(fpr_knn, tpr_knn, label=f'KNN (AUC={auc_knn:.2f})')
plt.plot([0,1], [0,1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Curva ROC")
plt.legend()
plt.show()

# %%
#PUNTO 6
import pandas as pd
# Suponiendo que elegimos de modelo logit o knn

# Cargar la base norespondieron
# norespondieron = pd.read_csv("norespondieron.csv")
# X_noresp = norespondieron[['col1', 'col2', ...]]  # reemplazar por tus columnas

# Realizar predicción de probabilidades de desocupación
# Si usamos LogisticRegression o KNN:
y_prob_noresp = modelo.predict_proba(X_noresp)[:, 1]
y_pred_noresp = (y_prob_noresp > 0.5).astype(int)  # 1 = desocupado, 0 = no desocupado

# Proporción de personas clasificadas como desocupadas
proporcion_desocupados = y_pred_noresp.sum() / len(y_pred_noresp)
print(f"Proporción de personas en 'norespondieron' clasificadas como desocupadas: {proporcion_desocupados:.3f}")

# Si queremos ver los índices de las personas clasificadas como desocupadas:
# desocupados = norespondieron[y_pred_noresp == 1]
# print(desocupados)
