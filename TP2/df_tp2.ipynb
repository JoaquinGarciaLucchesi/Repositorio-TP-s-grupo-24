# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
df = pd.read_excel(r"C:\Users\ldtes\usu_individual_T124.xlsx")
df_sorted =df[df['REGION'] == 1]
df_sorted["REGION"]="Gran Buenos Aires"

#Cambio de nombre de las variables de interés:
df_sorted = df_sorted.rename(columns={'CH04': 'Sexos Relevados'})
df_sorted = df_sorted.rename(columns={'NIVEL_ED': 'Nivel Educativo'})
df_sorted = df_sorted.rename(columns={'CH08': 'Cobertura Médica'})
df_sorted = df_sorted.rename(columns={'CH07': 'Estado Civil'})
df_sorted = df_sorted.rename(columns={'CAT_INAC': 'Categoría de Inactividad'})
df_sorted = df_sorted.rename(columns={'IPCF': "Ingreso Per Cápita Familiar"})
df_sorted = df_sorted.rename(columns={'CH06': "Años al momento de la encuesta"})
df_sorted = df_sorted.rename(columns={'CH09': "Sabe leer"})
df_sorted = df_sorted.rename(columns={'PP07G1': "Tiene Vacaciones Pagas"})
df_sorted = df_sorted.rename(columns={'PP07G2': "Cobra Aguinaldo"})
df_sorted = df_sorted.rename(columns={'CH10': "Asistió a una institución educativa"})
df_sorted= df_sorted.rename(columns={'PP10D':"Trabajó en el último año"})

#Adaptación de las variables de la EPH 2024 a la EPH 2004:
df_sorted['Sexos Relevados'] = df_sorted['Sexos Relevados'].replace({1: 'Varón', 2: 'Mujer'})
df_sorted['Nivel Educativo'] = df_sorted['Nivel Educativo'].replace({1: "Primaria Incompleta (incluye educación especial)",
2: "Primaria Completa",
3: "Secundaria Incompleta",
4: "Secundaria Completa",
5: "Superior Universitaria Incompleta",
6: "Superior Universitaria Completa",
7: "Sin instrucción",
9: "Ns./ Nr."})
df_sorted['Cobertura Médica'] = df_sorted['Cobertura Médica'].replace({1:"Obra social (incluye PAMI)",2: 'Mutual / Prepaga / Servicio de emergencia',3:"Planes y seguros públicos",4:"No paga ni le descuentan",12:"Ns./Nr.",13:"Obra social y Planes y Seguros Públicos", 
                                               23:"Mutual/prepaga/servicio de emergencia/Planes y Seguros Públicos",
                                                123:"Obra social, mutual / prepaga / servicio de emergencia/Planes y Seguros Públicos"})
df_sorted['Categoría de Inactividad'] = df_sorted['Categoría de Inactividad'].replace({1: "Jubilado / Pensionado",
2: "Rentista",
3: "Estudiante",
4: "Ama de casa",
5: "Menor de 6 años",
6: "Discapacitado",
7: "Otros"})
df_sorted['Sabe leer'] = df_sorted['Sabe leer'].replace({1: "Sí",
2: "No",
3: "Menor de 2 años"})
df_sorted["Tiene Vacaciones Pagas"] = df_sorted['Tiene Vacaciones Pagas'].replace({1: "Sí",
2: "No"})
df_sorted["Cobra Aguinaldo"] = df_sorted['Cobra Aguinaldo'].replace({1: "Sí",
2: "No"})
df_sorted["Asistió a una institución educativa"] = df_sorted['Asistió a una institución educativa'].replace({1: "Si, asiste",
2: "No asiste, pero asistió",
3: "Nunca asistió"})
df_sorted['ESTADO'] = df_sorted['ESTADO'].replace({0: "Entrevista individual no realizada (no respuesta al Cuestionario Individual)",
1: "Ocupado",
2: "Desocupado",
3: "Inactivo",
4: "Menor de 10 años"})

df_sorted["Trabajó en el último año"] = df_sorted['Trabajó en el último año'].replace({1: "Sí",
2: "No"})

df_sorted["Estado Civil"] = df_sorted['Estado Civil'].replace({1: "unido?",
2: "casado?",
3: "separado/a ó divorciado/a?",
4: "viudo/a?",
5: "soltero/a?"})
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_81252\389841110.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sorted["REGION"]="Gran Buenos Aires"
#                               CODUSU  ANO4  TRIMESTRE  NRO_HOGAR  COMPONENTE  \
# 245    TQRMNOSUWHLKMUCDEIJAH00855260  2024          1          1           1
# 246    TQRMNOSUWHLKMUCDEIJAH00855260  2024          1          1           2
# 247    TQRMNOSUWHLKMUCDEIJAH00855260  2024          1          1           3
# 255    TQSMNORWVHLLKQCDEIJAH00856914  2024          1          1           1
# 256    TQRMNOPQQHLOLRCDEIJAH00855133  2024          1          1           1
# ...                              ...   ...        ...        ...         ...
# 46045  TQRMNOPUQHKMKNCDEIJAH00861661  2024          1          1           1
# 46046  TQRMNOPUQHKMKNCDEIJAH00861661  2024          1          1           2
# 46047  TQRMNOPUQHKMKNCDEIJAH00861661  2024          1          1           3
# 46048  TQRMNOPUQHKMKNCDEIJAH00861661  2024          1          1           4
# 46049  TQRMNOPUQHKMKNCDEIJAH00861661  2024          1          1           5
#
#        H15             REGION MAS_500  AGLOMERADO  PONDERA  ...  PDECIFR  \
# 245      1  Gran Buenos Aires       S          33     1810  ...      NaN
# 246      1  Gran Buenos Aires       S          33     1810  ...      NaN
# 247      1  Gran Buenos Aires       S          33     1810  ...      NaN
# 255      1  Gran Buenos Aires       S          33     2368  ...      NaN
# 256      1  Gran Buenos Aires       S          33     1223  ...      NaN
# ...    ...                ...     ...         ...      ...  ...      ...
# 46045    1  Gran Buenos Aires       S          33     3410  ...      NaN
# 46046    2  Gran Buenos Aires       S          33     3410  ...      NaN
# 46047    2  Gran Buenos Aires       S          33     3410  ...      NaN
# 46048    2  Gran Buenos Aires       S          33     3410  ...      NaN
# 46049    2  Gran Buenos Aires       S          33     3410  ...      NaN
#
#       ADECIFR Ingreso Per Cápita Familiar  DECCFR IDECCFR RDECCFR GDECCFR  \
# 245        12                         0.0      12     NaN      12    12.0
# 246        12                         0.0      12     NaN      12    12.0
# 247        12                         0.0      12     NaN      12    12.0
# 255         6                    500000.0       9     NaN       9     9.0
# 256        12                         0.0      12     NaN      12    12.0
# ...       ...                         ...     ...     ...     ...     ...
# 46045      12                         0.0      12     NaN      12    12.0
# 46046      12                         0.0      12     NaN      12    12.0
# 46047      12                         0.0      12     NaN      12    12.0
# 46048      12                         0.0      12     NaN      12    12.0
# 46049      12                         0.0      12     NaN      12    12.0
#
#       PDECCFR  ADECCFR  PONDIH
# 245       NaN       12       0
# 246       NaN       12       0
# 247       NaN       12       0
# 255       NaN        9    3324
# 256       NaN       12       0
# ...       ...      ...     ...
# 46045     NaN       12       0
# 46046     NaN       12       0
# 46047     NaN       12       0
# 46048     NaN       12       0
# 46049     NaN       12       0
#
# [7051 rows x 177 columns]

# %%
#Cambio de nombre de las variables de interés de la EPH de 2004, 
#Así ,las columnas tienen en los dos registros el mismo nombre
df_1=pd.read_stata("usu_individual_T104.dta")
df_1=df_1.rename(columns={'ch04': 'Sexos Relevados'})
df_1= df_1.rename(columns={'region':'REGION'})
df_1=df_1[df_1['REGION'] == "Gran Buenos Aires"]
df_1= df_1.rename(columns={'ano4':'ANO4'})
df_1= df_1.rename(columns={'nivel_ed':'Nivel Educativo'})
df_1= df_1.rename(columns={'ch07':'Estado Civil'})
df_1= df_1.rename(columns={'ch08':'Cobertura Médica'})
df_1= df_1.rename(columns={"cat_inac":'Categoría de Inactividad'})
df_1= df_1.rename(columns={'ipcf':"Ingreso Per Cápita Familiar"})
df_1= df_1.rename(columns={'ch06':"Años al momento de la encuesta"})
df_1= df_1.rename(columns={'ch09':"Sabe leer"})
df_1= df_1.rename(columns={'pp07g1':"Tiene Vacaciones Pagas"})
df_1= df_1.rename(columns={'pp07g2':"Cobra Aguinaldo"})
df_1= df_1.rename(columns={'estado':"ESTADO"})
df_1= df_1.rename(columns={'pp10d':"Trabajó en el último año"})
df_1= df_1.rename(columns={'ch10':"Asistió a una institución educativa"})

# %%
df_2=df_1.filter(["Sexos Relevados","REGION","ANO4","Nivel Educativo","Estado Civil","Cobertura Médica","Categoría de Inactividad","Ingreso Per Cápita Familiar","Años al momento de la encuesta","Sabe leer",
"Tiene Vacaciones Pagas",
"Cobra Aguinaldo",
"ESTADO",
"Trabajó en el último año",
"Asistió a una institución educativa"])
df_3=df_sorted.filter(["Sexos Relevados","REGION","ANO4","Nivel Educativo","Estado Civil","Cobertura Médica","Categoría de Inactividad","Ingreso Per Cápita Familiar","Años al momento de la encuesta","Sabe leer",
"Tiene Vacaciones Pagas",
"Cobra Aguinaldo",
"ESTADO",
"Trabajó en el último año",
"Asistió a una institución educativa"])
df_3
# Out:
#       Sexos Relevados             REGION  ANO4  \
# 245             Mujer  Gran Buenos Aires  2024
# 246             Varón  Gran Buenos Aires  2024
# 247             Mujer  Gran Buenos Aires  2024
# 255             Varón  Gran Buenos Aires  2024
# 256             Mujer  Gran Buenos Aires  2024
# ...               ...                ...   ...
# 46045           Mujer  Gran Buenos Aires  2024
# 46046           Varón  Gran Buenos Aires  2024
# 46047           Varón  Gran Buenos Aires  2024
# 46048           Varón  Gran Buenos Aires  2024
# 46049           Mujer  Gran Buenos Aires  2024
#
#                                         Nivel Educativo  \
# 245                                   Primaria Completa
# 246                     Superior Universitaria Completa
# 247                     Superior Universitaria Completa
# 255                     Superior Universitaria Completa
# 256    Primaria Incompleta (incluye educación especial)
# ...                                                 ...
# 46045                             Secundaria Incompleta
# 46046                             Secundaria Incompleta
# 46047                             Secundaria Incompleta
# 46048                             Secundaria Incompleta
# 46049                 Superior Universitaria Incompleta
#
#                      Estado Civil            Cobertura Médica  \
# 245                      viudo/a?  Obra social (incluye PAMI)
# 246                       casado?  Obra social (incluye PAMI)
# 247                       casado?  Obra social (incluye PAMI)
# 255                    soltero/a?  Obra social (incluye PAMI)
# 256                      viudo/a?  Obra social (incluye PAMI)
# ...                           ...                         ...
# 46045  separado/a ó divorciado/a?  Obra social (incluye PAMI)
# 46046                  soltero/a?  Obra social (incluye PAMI)
# 46047                  soltero/a?  Obra social (incluye PAMI)
# 46048                  soltero/a?  Obra social (incluye PAMI)
# 46049                  soltero/a?  Obra social (incluye PAMI)
#
#       Categoría de Inactividad  Ingreso Per Cápita Familiar  \
# 245                          0                          0.0
# 246                          0                          0.0
# 247                          0                          0.0
# 255                          0                     500000.0
# 256      Jubilado / Pensionado                          0.0
# ...                        ...                          ...
# 46045                        0                          0.0
# 46046                        0                          0.0
# 46047                        0                          0.0
# 46048                        0                          0.0
# 46049                        0                          0.0
#
#        Años al momento de la encuesta Sabe leer Tiene Vacaciones Pagas  \
# 245                                85        Sí                    0.0
# 246                                59        Sí                    0.0
# 247                                57        Sí                     Sí
# 255                                26        Sí                    0.0
# 256                                88        Sí                    NaN
# ...                               ...       ...                    ...
# 46045                              43        Sí                     Sí
# 46046                              21        Sí                    NaN
# 46047                              20        Sí                    NaN
# 46048                              11        Sí                    NaN
# 46049                              24        Sí                    NaN
#
#       Cobra Aguinaldo                                             ESTADO  \
# 245               0.0                                            Ocupado
# 246               0.0                                            Ocupado
# 247                Sí                                            Ocupado
# 255               0.0                                            Ocupado
# 256               NaN                                           Inactivo
# ...               ...                                                ...
# 46045              Sí                                            Ocupado
# 46046             NaN  Entrevista individual no realizada (no respues...
# 46047             NaN  Entrevista individual no realizada (no respues...
# 46048             NaN  Entrevista individual no realizada (no respues...
# 46049             NaN  Entrevista individual no realizada (no respues...
#
#       Trabajó en el último año Asistió a una institución educativa
# 245                        NaN             No asiste, pero asistió
# 246                        NaN             No asiste, pero asistió
# 247                        NaN             No asiste, pero asistió
# 255                        NaN             No asiste, pero asistió
# 256                        NaN             No asiste, pero asistió
# ...                        ...                                 ...
# 46045                      NaN             No asiste, pero asistió
# 46046                      NaN                          Si, asiste
# 46047                      NaN                          Si, asiste
# 46048                      NaN                          Si, asiste
# 46049                      NaN                          Si, asiste
#
# [7051 rows x 15 columns]

# %%
lista_columnas=[
    "Sexos Relevados",
    "REGION",
    "ANO4",
    "Nivel Educativo",
    "Cobertura Médica",
    "Categoría de Inactividad",
    "Ingreso Per Cápita Familiar",
    "Años al momento de la encuesta",
    "Sabe leer",
    "Cobra Aguinaldo",
    "Estado Civil","Tiene Vacaciones Pagas"
    "ESTADO",
    "Trabajó en el último año",
    "Asistió a una institución educativa"]
juntas_df=pd.merge(df_2,df_3,how="outer")
juntas_df["Ingreso Per Cápita Familiar"] = juntas_df["Ingreso Per Cápita Familiar"].apply(round)
juntas_df["ANO4"] = juntas_df["ANO4"].apply(round)

juntas_df
# Out:
#       Sexos Relevados             REGION  ANO4  \
# 0               Mujer  Gran Buenos Aires  2004
# 1               Mujer  Gran Buenos Aires  2004
# 2               Mujer  Gran Buenos Aires  2004
# 3               Mujer  Gran Buenos Aires  2004
# 4               Mujer  Gran Buenos Aires  2004
# ...               ...                ...   ...
# 14693           Varón  Gran Buenos Aires  2024
# 14694           Varón  Gran Buenos Aires  2024
# 14695           Varón  Gran Buenos Aires  2024
# 14696           Varón  Gran Buenos Aires  2024
# 14697           Varón  Gran Buenos Aires  2024
#
#                          Nivel Educativo Estado Civil  \
# 0                      Primaria Completa       Casado
# 1                      Primaria Completa       Casado
# 2                      Primaria Completa       Casado
# 3                      Primaria Completa       Casado
# 4                      Primaria Completa       Casado
# ...                                  ...          ...
# 14693  Superior Universitaria Incompleta       unido?
# 14694  Superior Universitaria Incompleta       unido?
# 14695  Superior Universitaria Incompleta     viudo/a?
# 14696  Superior Universitaria Incompleta     viudo/a?
# 14697  Superior Universitaria Incompleta     viudo/a?
#
#                             Cobertura Médica Categoría de Inactividad  \
# 0      Mutual/Prepaga/Servicio de emergencia                      0.0
# 1      Mutual/Prepaga/Servicio de emergencia                      0.0
# 2      Mutual/Prepaga/Servicio de emergencia              Ama de casa
# 3      Mutual/Prepaga/Servicio de emergencia              Ama de casa
# 4      Mutual/Prepaga/Servicio de emergencia              Ama de casa
# ...                                      ...                      ...
# 14693             Obra social (incluye PAMI)              Ama de casa
# 14694             Obra social (incluye PAMI)    Jubilado / Pensionado
# 14695             Obra social (incluye PAMI)                        0
# 14696             Obra social (incluye PAMI)                        0
# 14697             Obra social (incluye PAMI)                        0
#
#        Ingreso Per Cápita Familiar Años al momento de la encuesta Sabe leer  \
# 0                              736                           59.0        Sí
# 1                             3416                           46.0        Sí
# 2                               50                           68.0        Sí
# 3                              200                           54.0        Sí
# 4                              200                           61.0        Sí
# ...                            ...                            ...       ...
# 14693                        46667                             45        Sí
# 14694                       359000                             91        Sí
# 14695                            0                             61        Sí
# 14696                            0                             68        Sí
# 14697                       447500                             59        Sí
#
#       Tiene Vacaciones Pagas Cobra Aguinaldo    ESTADO  \
# 0                        0.0             0.0   Ocupado
# 1                        0.0             0.0   Ocupado
# 2                        0.0             0.0  Inactivo
# 3                        0.0             0.0  Inactivo
# 4                        0.0             0.0  Inactivo
# ...                      ...             ...       ...
# 14693                    NaN             NaN  Inactivo
# 14694                    NaN             NaN  Inactivo
# 14695                     Sí              Sí   Ocupado
# 14696                    0.0             0.0   Ocupado
# 14697                    0.0             0.0   Ocupado
#
#       Trabajó en el último año Asistió a una institución educativa
# 0                          0.0             No asiste, pero asistió
# 1                          0.0             No asiste, pero asistió
# 2                          0.0             No asiste, pero asistió
# 3                          0.0             No asiste, pero asistió
# 4                          0.0             No asiste, pero asistió
# ...                        ...                                 ...
# 14693                      NaN             No asiste, pero asistió
# 14694                      NaN             No asiste, pero asistió
# 14695                      NaN             No asiste, pero asistió
# 14696                      NaN             No asiste, pero asistió
# 14697                      NaN             No asiste, pero asistió
#
# [14698 rows x 15 columns]

# %%
# Count NaN values per column
nan_counts_per_column = juntas_df.isna().sum()
column_with_most = nan_counts_per_column.idxmax()
maximo_de_veces = nan_counts_per_column.max()
nan_counts_2do=nan_counts_per_column.index[1]
nan_counts_2do=nan_counts_per_column.index[2]


print( f"'NaN'aparece más veces en la columna '{column_with_most}' ({maximo_de_veces} veces)")
# Out:
# 'NaN'aparece más veces en la columna 'Trabajó en el último año' (6740 veces)

# %%
nan_counts_per_column = juntas_df.isna().sum()
print(nan_counts_per_column)
# Out:
# Sexos Relevados                           0
# REGION                                    0
# ANO4                                      0
# Nivel Educativo                           0
# Estado Civil                              0
# Cobertura Médica                          0
# Categoría de Inactividad                  0
# Ingreso Per Cápita Familiar               0
# Años al momento de la encuesta            0
# Sabe leer                                 0
# Tiene Vacaciones Pagas                 3827
# Cobra Aguinaldo                        3827
# ESTADO                                    0
# Trabajó en el último año               6740
# Asistió a una institución educativa       0
# dtype: int64

# %%
#Sección II, Ejercicio 3)

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(5,6))
ax=sns.histplot(data=juntas_df, x="ANO4", stat='count', hue="Sexos Relevados", multiple="stack") 
plt.suptitle("Distribución por sexo de la población evaluada")
plt.xlabel("Años")
plt.ylabel("Cantidad dentro de la muestra",rotation=0, labelpad=90)
plt.xticks([2004, 2024])
legend.set_title(None)
ax.get_legend()
